# %% [markdown]
# #### cleaning students survey data

# %%
import pandas as pd
students_data=pd.read_csv("students_data.csv")
students_data.head()
# Out:
#    I enjoy learning mathematics  \
# 0                         Agree
# 1                Strongly Agree
# 2                Strongly Agree
# 3                Strongly Agree
# 4                       Neutral
#
#      I feel confident when solving math problems   \
# 0                                           Agree
# 1                                        Disagree
# 2                                           Agree
# 3                                  Strongly agree
# 4                                         Neutral
#
#     Mathematics is useful in real life    \
# 0                         Strongly agree
# 1                                Neutral
# 2                         Strongly agree
# 3                         Strongly agree
# 4                      Strongly disagree
#
#     I get anxious during mathematics lessons    \
# 0                                     Disagree
# 1                                      Neutral
# 2                                        Agree
# 3                               Strongly Agree
# 4                                      Neutral
#
#     I believe I can perform well in mathematics    \
# 0                                           Agree
# 1                                           Agree
# 2                                           Agree
# 3                                  Strongly agree
# 4                               Strongly disagree
#
#     There are enough mathematics textbooks for all students    \
# 0                                           Disagree
# 1                                  Strongly Disagree
# 2                                              Agree
# 3                                              Agree
# 4                                            Neutral
#
#     The school provides mathematical instruments (rulers, compasses, sets)    \
# 0                                  Strongly Disagree
# 1                                              Agree
# 2                                  Strongly Disagree
# 3                                            Neutral
# 4                                           Disagree
#
#     Teachers use relevant teaching aids like charts and models    \
# 0                                           Disagree
# 1                                           Disagree
# 2                                           Disagree
# 3                                  Strongly Disagree
# 4                                            Neutral
#
#     Students have access to practice tests and past papers for mathematics    \
# 0                                           Disagree
# 1                                              Agree
# 2                                     Strongly Agree
# 3                                  Strongly Disagree
# 4                                            Neutral
#
#     Learning materials are updated to reflect the current syllabus    \
# 0                                              Agree
# 1                                            Neutral
# 2                                              Agree
# 3                                              Agree
# 4                                  Strongly disagree
#
#   NAME OF THE SCHOOL. SUB-COUNTY COUNTY  GENDER
# 0        Kaudha_Mixed      Wagai  Siaya    Male
# 1        Kaudha_Mixed      Wagai  Siaya  Female
# 2        Kaudha_Mixed      Wagai  Siaya    Male
# 3        Kaudha_Mixed      Wagai  Siaya    Male
# 4        Kaudha_Mixed      Wagai  Siaya  Female

# %% [markdown]
# ### uploading teachers data

# %%
teachers_data=pd.read_csv("teachers_data.csv")
teachers_data.head()
# Out:
#     Mathematics teachers in this school attend training workshops regularly.    \
# 0                                              Agree
# 1                                     Strongly agree
# 2                                              Agree
# 3                                              Agree
# 4                                              Agree
#
#     The training has helped teachers improve how they teach mathematics.    \
# 0                                              Agree
# 1                                     Strongly Agree
# 2                                              Agree
# 3                                            Neutral
# 4                                     Strongly Agree
#
#     The training programs cover the current curriculum and exams.    \
# 0                                     Strongly agree
# 1                                                NaN
# 2                                              Agree
# 3                                            Neutral
# 4                                              Agree
#
#     Teachers share what they learn from training with others  \
# 0                                              Agree
# 1                                     Strongly agree
# 2                                              Agree
# 3                                              Agree
# 4                                     Strongly agree
#
#     The school administration supports teachers to attend training programs  \
# 0                                              Agree
# 1                                              Agree
# 2                                              Agree
# 3                                              Agree
# 4                                              Agree
#
#   NAME  OF THE SCHOOL SUB-COUNTY COUNTY  Score
# 0        Kaudha_Mixed      Wagai  Siaya    NaN
# 1        Kaudha_Mixed      Wagai  Siaya    NaN
# 2      Budokomi_Mixed      Busia  Busia    NaN
# 3      Budokomi_Mixed      Busia  Busia    NaN
# 4        Malele_Mixed      Wagai  Siaya    NaN

# %% [markdown]
# ### uploading kcse data

# %%
kcse=pd.read_csv("kcse_data1.csv")
kcse.head()
# Out:
#          SCHOOL  GENDER  EXAM_YEAR SUB-COUNTY COUNTY GRADE
# 0  Malele_Mixed    MALE       2024      Wagai  siaya    B+
# 1  Malele_Mixed    MALE       2024      Wagai  siaya     A
# 2  Malele_Mixed    MALE       2024      Wagai  siaya    C-
# 3  Malele_Mixed    MALE       2024      Wagai  siaya    B-
# 4  Malele_Mixed  FEMALE       2024      Wagai  siaya    D+

# %% [markdown]
# ### kcse grades to points conversion

# %%
grades_map={'A':12,'A-':11,'B+':10,'B':9,'B-':8,'C+':7,'C':6,'C-':5,'D+':4,'D':3,'D-':2,'E':1}
kcse['GRADE_POINTS']=kcse['GRADE'].map(grades_map)
kcse.head()
# Out:
#          SCHOOL  GENDER  EXAM_YEAR SUB-COUNTY COUNTY GRADE  GRADE_POINTS
# 0  Malele_Mixed    MALE       2024      Wagai  siaya    B+          10.0
# 1  Malele_Mixed    MALE       2024      Wagai  siaya     A          12.0
# 2  Malele_Mixed    MALE       2024      Wagai  siaya    C-           5.0
# 3  Malele_Mixed    MALE       2024      Wagai  siaya    B-           8.0
# 4  Malele_Mixed  FEMALE       2024      Wagai  siaya    D+           4.0

# %% [markdown]
# #### converting year column to string

# %%
# year to string
kcse['EXAM_YEAR']=kcse['EXAM_YEAR'].astype(str)
kcse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1700 entries, 0 to 1699
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SCHOOL        1700 non-null   object
#  1   GENDER        1700 non-null   object
#  2   EXAM_YEAR     1700 non-null   object
#  3   SUB-COUNTY    1700 non-null   object
#  4   COUNTY        1700 non-null   object
#  5   GRADE         1699 non-null   object
#  6   GRADE_POINTS  1698 non-null   float64
# dtypes: float64(1), object(6)
# memory usage: 93.1+ KB

# %% [markdown]
# ### cleaning students_survey data

# %% [markdown]
# #### clean column names

# %%
students_data=students_data.columns.str.strip()

# %% [markdown]
# ##### define likert scale mapping

# %%
likert_map={"Strongly Disagree": 1,"Disagree": 2,"Neutral": 3,"Agree":4,"Strongly Agree": 5
}

# %% [markdown]
# #### List attitude statement columns

# %%
attitude_cols=[
    "I Enjoy Learning Mathematics",
    "I Feel Confident When Solving Math Problems",
    "Mathematics Is Useful In Real Life",
    "I Get Anxious During Mathematics Lessons",
    "I Believe I Can Perform Well In Mathematics"
]

# %% [markdown]
# ### list availability of materials columns

# %%
materials_cols=[
    "There Are Enough Mathematics Textbooks For All Students",
    "The School Provides Mathematical Instruments (Rulers, Compasses, Sets)",
    "Teachers Use Relevant Teaching Aids Like Charts And Models",
    "Students Have Access To Practice Tests And Past Papers For Mathematics",
    "Learning Materials Are Updated To Reflect The Current Syllabus"
]

# %% [markdown]
# #### convert likert choices to numeric using likert scale mapping defined above

# %%
students_data[attitude_cols + materials_cols] = students_data[attitude_cols + materials_cols].apply(lambda x: x.str.strip().str.title())
for col in attitude_cols + materials_cols:
    students_data[col] = students_data[col].map(likert_map)

# %% [markdown]
# #### Reverse the anxiety column

# %%
#reversing the an xiety column
students_data["I Get Anxious During Mathematics Lessons"] = (
    6 - students_data["I Get Anxious During Mathematics Lessons"]
)

# %% [markdown]
# #### Compute row-wise average for attitude

# %%
# attitude average
students_data["Attitude"] = students_data[attitude_cols].mean(axis=1)

# %% [markdown]
# #### Compute Row-wise Average for materials

# %%
# material average
students_data["Availability of learning materials"]= students_data[materials_cols].mean(axis=1)

# %% [markdown]
# ### Check few rows to accertain the result

# %%
students_data.head()
# Out:
#    I Enjoy Learning Mathematics  I Feel Confident When Solving Math Problems  \
# 0                           4.0                                            4
# 1                           5.0                                            2
# 2                           5.0                                            4
# 3                           5.0                                            5
# 4                           3.0                                            3
#
#    Mathematics Is Useful In Real Life  \
# 0                                 5.0
# 1                                 3.0
# 2                                 5.0
# 3                                 5.0
# 4                                 1.0
#
#    I Get Anxious During Mathematics Lessons  \
# 0                                       4.0
# 1                                       3.0
# 2                                       2.0
# 3                                       1.0
# 4                                       3.0
#
#    I Believe I Can Perform Well In Mathematics  \
# 0                                          4.0
# 1                                          4.0
# 2                                          4.0
# 3                                          5.0
# 4                                          1.0
#
#    There Are Enough Mathematics Textbooks For All Students  \
# 0                                                2.0
# 1                                                1.0
# 2                                                4.0
# 3                                                4.0
# 4                                                3.0
#
#    The School Provides Mathematical Instruments (Rulers, Compasses, Sets)  \
# 0                                                1.0
# 1                                                4.0
# 2                                                1.0
# 3                                                3.0
# 4                                                2.0
#
#    Teachers Use Relevant Teaching Aids Like Charts And Models  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  1
# 4                                                  3
#
#    Students Have Access To Practice Tests And Past Papers For Mathematics  \
# 0                                                2.0
# 1                                                4.0
# 2                                                5.0
# 3                                                1.0
# 4                                                3.0
#
#    Learning Materials Are Updated To Reflect The Current Syllabus  \
# 0                                                4.0
# 1                                                3.0
# 2                                                4.0
# 3                                                4.0
# 4                                                1.0
#
#   Name Of The School. Sub-County County  Gender  Attitude  \
# 0        Kaudha_Mixed      Wagai  Siaya    Male       4.2
# 1        Kaudha_Mixed      Wagai  Siaya  Female       3.4
# 2        Kaudha_Mixed      Wagai  Siaya    Male       4.0
# 3        Kaudha_Mixed      Wagai  Siaya    Male       4.2
# 4        Kaudha_Mixed      Wagai  Siaya  Female       2.2
#
#    Availability of learning materials
# 0                                 2.2
# 1                                 2.8
# 2                                 3.2
# 3                                 2.6
# 4                                 2.4

# %% [markdown]
# ##### confirm the data-types of the columns

# %%
students_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 604 entries, 0 to 603
# Data columns (total 16 columns):
#  #   Column                                                                  Non-Null Count  Dtype
# ---  ------                                                                  --------------  -----
#  0   I Enjoy Learning Mathematics                                            600 non-null    float64
#  1   I Feel Confident When Solving Math Problems                             604 non-null    int64
#  2   Mathematics Is Useful In Real Life                                      603 non-null    float64
#  3   I Get Anxious During Mathematics Lessons                                602 non-null    float64
#  4   I Believe I Can Perform Well In Mathematics                             600 non-null    float64
#  5   There Are Enough Mathematics Textbooks For All Students                 602 non-null    float64
#  6   The School Provides Mathematical Instruments (Rulers, Compasses, Sets)  603 non-null    float64
#  7   Teachers Use Relevant Teaching Aids Like Charts And Models              604 non-null    int64
#  8   Students Have Access To Practice Tests And Past Papers For Mathematics  601 non-null    float64
#  9   Learning Materials Are Updated To Reflect The Current Syllabus          602 non-null    float64
#  10  Name Of The School.                                                     604 non-null    object
#  11  Sub-County                                                              604 non-null    object
#  12  County                                                                  604 non-null    object
#  13  Gender                                                                  604 non-null    object
#  14  Attitude                                                                604 non-null    float64
#  15  Availability of learning materials                                      604 non-null    float64
# dtypes: float64(10), int64(2), object(4)
# memory usage: 75.6+ KB

# %% [markdown]
# #### Save the new dataframe in csv format

# %%
# saving the new dataframe
students_data.to_csv("new_students_data.csv", index=False)

# %%
students_data.head()
# Out:
#    I Enjoy Learning Mathematics  I Feel Confident When Solving Math Problems  \
# 0                           4.0                                            4
# 1                           5.0                                            2
# 2                           5.0                                            4
# 3                           5.0                                            5
# 4                           3.0                                            3
#
#    Mathematics Is Useful In Real Life  \
# 0                                 5.0
# 1                                 3.0
# 2                                 5.0
# 3                                 5.0
# 4                                 1.0
#
#    I Get Anxious During Mathematics Lessons  \
# 0                                       4.0
# 1                                       3.0
# 2                                       2.0
# 3                                       1.0
# 4                                       3.0
#
#    I Believe I Can Perform Well In Mathematics  \
# 0                                          4.0
# 1                                          4.0
# 2                                          4.0
# 3                                          5.0
# 4                                          1.0
#
#    There Are Enough Mathematics Textbooks For All Students  \
# 0                                                2.0
# 1                                                1.0
# 2                                                4.0
# 3                                                4.0
# 4                                                3.0
#
#    The School Provides Mathematical Instruments (Rulers, Compasses, Sets)  \
# 0                                                1.0
# 1                                                4.0
# 2                                                1.0
# 3                                                3.0
# 4                                                2.0
#
#    Teachers Use Relevant Teaching Aids Like Charts And Models  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  1
# 4                                                  3
#
#    Students Have Access To Practice Tests And Past Papers For Mathematics  \
# 0                                                2.0
# 1                                                4.0
# 2                                                5.0
# 3                                                1.0
# 4                                                3.0
#
#    Learning Materials Are Updated To Reflect The Current Syllabus  \
# 0                                                4.0
# 1                                                3.0
# 2                                                4.0
# 3                                                4.0
# 4                                                1.0
#
#   Name Of The School. Sub-County County  Gender  Attitude  \
# 0        Kaudha_Mixed      Wagai  Siaya    Male       4.2
# 1        Kaudha_Mixed      Wagai  Siaya  Female       3.4
# 2        Kaudha_Mixed      Wagai  Siaya    Male       4.0
# 3        Kaudha_Mixed      Wagai  Siaya    Male       4.2
# 4        Kaudha_Mixed      Wagai  Siaya  Female       2.2
#
#    Availability of learning materials
# 0                                 2.2
# 1                                 2.8
# 2                                 3.2
# 3                                 2.6
# 4                                 2.4

# %%
school_index = students_data.columns.get_loc("Name Of The School.")
print(school_index)
# Out:
# 10

# %% [markdown]
# ##### dropping columns before school name to get students_data3

# %%
students_data3 = students_data.iloc[:, 10:]

# %%
students_data3.head()
# Out:
#   Name Of The School. Sub-County County  Gender  Attitude  \
# 0        Kaudha_Mixed      Wagai  Siaya    Male       4.2
# 1        Kaudha_Mixed      Wagai  Siaya  Female       3.4
# 2        Kaudha_Mixed      Wagai  Siaya    Male       4.0
# 3        Kaudha_Mixed      Wagai  Siaya    Male       4.2
# 4        Kaudha_Mixed      Wagai  Siaya  Female       2.2
#
#    Availability of learning materials
# 0                                 2.2
# 1                                 2.8
# 2                                 3.2
# 3                                 2.6
# 4                                 2.4

# %%
# saving the third students data after dropping all columns before school name
students_data3.to_csv("students_data3.csv", index=False)

# %%
kcse.head()
# Out:
#          SCHOOL  GENDER EXAM_YEAR SUB-COUNTY COUNTY GRADE  GRADE_POINTS
# 0  Malele_Mixed    MALE      2024      Wagai  siaya    B+          10.0
# 1  Malele_Mixed    MALE      2024      Wagai  siaya     A          12.0
# 2  Malele_Mixed    MALE      2024      Wagai  siaya    C-           5.0
# 3  Malele_Mixed    MALE      2024      Wagai  siaya    B-           8.0
# 4  Malele_Mixed  FEMALE      2024      Wagai  siaya    D+           4.0

# %% [markdown]
# #### save processed kcse data

# %%
kcse.to_csv("kcse2.csv",index=False)
